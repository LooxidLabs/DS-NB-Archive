# %%
import pandas as pd
import boto3
import json
import pymongo
import pandas as pd

# %%
from datetime import timedelta
from datetime import datetime, timezone
from typing import Any, List, Optional, Tuple
from pytz import UTC

# %%
# MongoDB 연결 문자열을 설정합니다.
connection_string = "mongodb://looxidlabs:looxidlabs.vkdlxld!@3.36.42.241:39632/m-project-dev?authSource=admin&readPreference=primary&directConnection=true&ssl=false"


class MongoDBChecker():
    def __init__(self, connection_string : str, dev_mode : bool = True) -> None:
        self.client : str = pymongo.MongoClient(connection_string)
        self.db_name : str = "focusmate-dev"
        if dev_mode == False:
            self.db_name = "focusmate"
            
        
    def get_user_id_from_email(self, email : str) -> Optional[str]:
        """
            Find the user id from user's email. If not found, return None
        """
        
        db : pymongo.database.Database = self.client[self.db_name]
        user_collection : pymongo.collection.Collection = db["users"]
        
        result : List[Any] = user_collection.find_one({"email": email})
        try:
            user_id : str = result["_id"]

            return user_id
        except:
            return None
    
    def _convert_timestamp(self, start_time : datetime, start_delay : int = 0, end_delay : int = 1) -> Tuple[int, int]:
        """
        일단은 임시로 이렇게 해두고 정석적인 시간 변환은 나중에 바꾸도록 하자
        """
        
        return datetime.fromtimestamp((start_time - timedelta(minutes=start_delay) - timedelta(hours=18)).timestamp()), datetime.fromtimestamp((start_time + timedelta(minutes=end_delay) - timedelta(hours=18)).timestamp())
    
    def get_focustimer_id_from_user_id(self, user_id : str, start_time : datetime) -> Optional[str]:
        """
            Toto
        """
        
        db : pymongo.database.Database = self.client[self.db_name]
        focustimer_collection : pymongo.collection.Collection = db["focustimers"]
            
        start_timestamp, end_timestamp = self._convert_timestamp(start_time)
        
        print(start_time, start_timestamp, end_timestamp)
            
        query = {
                    "userId": user_id,
                    "startedAt": {
                        "$gte": start_timestamp,
                        "$lte": end_timestamp
                    }
                }
        
        result = list(focustimer_collection.find(query))
        
        try:
            result = result[-1]
            focus_timer_id = result["_id"]

            return focus_timer_id
        except IndexError:
            return None
        
    def get_focustimer_ids_from_user_id_and_range(self, user_id : str, start_time : datetime, duration : timedelta) -> Optional[List[str]]:
        """
        """
        
        db : pymongo.database.Database = self.client[self.db_name]
        focustimer_collection : pymongo.collection.Collection = db["focustimers"]
            
        start_timestamp, end_timestamp = self._convert_timestamp(start_time)
        
        print(start_time, start_timestamp, end_timestamp)
            
        query = {
                    "userId": user_id,
                    "startedAt": {
                        "$gte": start_timestamp,
                        "$lte": start_timestamp + duration,
                    }
                }
        
        result = list(focustimer_collection.find(query))
        
        return result
        
        try:
            result = result[-1]
            focus_timer_id = result["_id"]

            return focus_timer_id
        except IndexError:
            return None
        
    def get_name_from_user_id(self, user_id : str) -> Optional[str]:
        """
        """
        
        db : pymongo.database.Database = self.client[self.db_name]
        users_collection : pymongo.collection.Collection = db["users"]
            
        query = {"_id": user_id}
        
        result = users_collection.find_one(query)
        
        if result:
            return result["nickname"]
        return None

    
def csv_converter(path : str) -> pd.DataFrame:
    df = pd.read_csv(path)
    df["Date"] = df["Date"].astype(str)
    df["IsDev"] = df["IsDev"].astype(bool)
    
    df['datetime'] = df['Date'] + ' ' + df['Start']

    # "Date"와 "Time" 열은 더 이상 필요하지 않으므로 삭제합니다.
    df.drop(['Date', 'Start'], axis=1, inplace=True)

    df['datetime'] = pd.to_datetime(df['datetime'], format='%y.%m.%d. %H:%M')
    
    return df

def add_ids_in_df(df : pd.DataFrame) -> pd.DataFrame:
    user_ids = []
    focus_timer_ids = []


    for idx, row in df.iterrows():
        checker = MongoDBChecker(connection_string, dev_mode=row["IsDev"])

        user_id = checker.get_user_id_from_email(row["Email"])
        result = checker.get_focustimer_ids_from_user_id_and_range(user_id, row["datetime"].tz_localize(UTC), timedelta(minutes=1))
        
        print(row["Name"], row["Label"], row["Trial"], user_id)
        print(result)
        
        try:
            user_ids.append(result[-1]["userId"])
            focus_timer_ids.append(result[-1]["_id"])
        except:
            continue
        
    df["user_id"] = user_ids
    df["focus_timer_id"] = focus_timer_ids
    
    return df

# %%
df = csv_converter("/Users/jooyoung/Desktop/스트룹/스트룹.csv")

# %%
df
# Out:
#    Name                                Email   Label  Trial  Wrong Answer  \
# 0   조문규              jooyoung.kim@epitech.eu    Rest      1             0
# 1   조문규              jooyoung.kim@epitech.eu  Stroop      1             1
# 2   조문규              jooyoung.kim@epitech.eu    Rest      2             0
# 3   조문규              jooyoung.kim@epitech.eu  Stroop      2             0
# 4   조문규              jooyoung.kim@epitech.eu    Rest      3             0
# 5   조문규              jooyoung.kim@epitech.eu  Stroop      3             0
# 6   공지현                     gjh2672@nate.com    Rest      1             0
# 7   공지현                     gjh2672@nate.com  Stroop      1             0
# 8   공지현                     gjh2672@nate.com    Rest      2             0
# 9   공지현                     gjh2672@nate.com  Stroop      2             0
# 10  공지현                     gjh2672@nate.com    Rest      3             0
# 11  공지현                     gjh2672@nate.com  Stroop      3             1
# 12  유영석                  modern331@naver.com    Rest      1             0
# 13  유영석                  modern331@naver.com  Stroop      1             0
# 14  유영석                  modern331@naver.com    Rest      2             0
# 15  유영석                  modern331@naver.com  Stroop      2             0
# 16  유영석                  modern331@naver.com    Rest      3             0
# 17  유영석                  modern331@naver.com  Stroop      3             0
# 18  임은수                    les0807@kakao.com    Rest      1             0
# 19  임은수                    les0807@kakao.com  Stroop      1             1
# 20  임은수                    les0807@kakao.com    Rest      2             0
# 21  임은수                    les0807@kakao.com  Stroop      2             0
# 22  임은수                    les0807@kakao.com    Rest      3             0
# 23  임은수                    les0807@kakao.com  Stroop      3             1
# 24  서지은  bhp8bghcq7@privaterelay.appleid.com    Rest      1             0
# 25  서지은  bhp8bghcq7@privaterelay.appleid.com  Stroop      1             1
# 26  서지은  bhp8bghcq7@privaterelay.appleid.com    Rest      2             0
# 27  서지은  bhp8bghcq7@privaterelay.appleid.com  Stroop      2             0
# 28  서지은  bhp8bghcq7@privaterelay.appleid.com    Rest      3             0
# 29  서지은  bhp8bghcq7@privaterelay.appleid.com  Stroop      3             0
# 30  김필수                   gorh1234@gmail.com    Rest      1             0
# 31  김필수                   gorh1234@gmail.com  Stroop      1             1
# 32  김필수                   gorh1234@gmail.com    Rest      2             0
 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('65489a443c7d07e9092f7979'), ObjectId('65489a4e3c7d07e9092f797f'), ObjectId('65489a583c7d07e9092f7985'), ObjectId('65489a623c7d07e9092f798b'), ObjectId('65489a6c3c7d07e9092f7991'), ObjectId('65489a763c7d07e9092f799d')], 'startedAt': datetime.datetime(2023, 11, 6, 7, 48, 10, 26000), 'updatedAt': datetime.datetime(2023, 11, 6, 7, 49, 13, 361000), 'completedAt': datetime.datetime(2023, 11, 6, 7, 49, 13, 361000)}]
# 2023-11-06 16:49:00+00:00 2023-11-06 07:49:00 2023-11-06 07:50:00
# 조문규 Stroop 1 64f02e44db83ec994f4458ac
# [{'_id': ObjectId('65489a7d3c7d07e9092f79b0'), 'userId': ObjectId('64f02e44db83ec994f4458ac'), 'time': 71, 'pureFocusTime': 24, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 33.80281690140845, 'efficiencyHCount': 0, 'efficiencyMCount': 5, 'efficiencyLCount': 1, 'capacity': 16.725566151455823, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('65489a873c7d07e9092f79b4'), ObjectId('65489a913c7d07e9092f79ba'), ObjectId('65489a9b3c7d07e9092f79c0'), ObjectId('65489aa53c7d07e9092f79d7'), ObjectId('65489ab03c7d07e9092f79dd'), ObjectId('65489aba3c7d07e9092f79e3'), ObjectId('65489ac43c7d07e9092f79e9')], 'startedAt': datetime.datetime(2023, 11, 6, 7, 49, 17, 374000), 'updatedAt': datetime.datetime(2023, 11, 6, 7, 50, 30, 918000), 'completedAt': datetime.datetime(2023, 11, 6, 7, 50, 29, 800000)}]
# 2023-11-06 16:50:00+00:00 2023-11-06 07:50:00 2023-11-06 07:51:00
# 조문규 Rest 2 64f02e44db83ec994f4458ac
# [{'_id': ObjectId('65489ad33c7d07e9092f79fc'), 'userId': ObjectId('64f02e44db83ec994f4458ac'), 'time': 60, 'pureFocusTime': 14, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 23.333333333333332, 'efficiencyHCount': 4, 'efficiencyMCount': 1, 'efficiencyLCount': 0, 'capacity': 26.479527140806645, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('65489add3c7d07e9092f7a03'), ObjectId('65489ae73c7d07e9092f7a09'), ObjectId('65489af13c7d07e9092f7a12'), ObjectId('65489afc3c7d07e9092f7a18'), ObjectId('65489b063c7d07e9092f7a1e')], 'startedAt': datetime.datetime(2023, 11, 6, 7, 50, 43, 259000), 'updatedAt': datetime.datetime(2023, 11, 6, 7, 51, 45, 267000), 'completedAt': datetime.datetime(2023, 11, 6, 7, 51, 45, 266000)}]
# 2023-11-06 16:51:00+00:00 2023-11-06 07:51:00 2023-11-06 07:52:00
# 조문규 Stroop 2 64f02e44db83ec994f4458ac
# [{'_id': ObjectId('65489b193c7d07e9092f7a37'), 'userId': ObjectId('64f02e44db83ec994f4458ac'), 'time': 63, 'pureFocusTime': 16, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 25.396825396825395, 'efficiencyHCount': 0, 'efficiencyMCount': 6, 'efficiencyLCount': 0, 'capacity': 19.2492032492569, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId
 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [], 'startedAt': datetime.datetime(2023, 11, 6, 5, 8, 43, 120000), 'updatedAt': datetime.datetime(2023, 11, 6, 5, 8, 49, 717000), 'completedAt': datetime.datetime(2023, 11, 6, 5, 8, 49, 716000)}, {'_id': ObjectId('654874ea80e107ec52ce1ba8'), 'userId': ObjectId('6541ef360d097eeb1f713c94'), 'time': 60, 'pureFocusTime': 25, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 41.66666666666667, 'efficiencyHCount': 0, 'efficiencyMCount': 4, 'efficiencyLCount': 1, 'capacity': 23.65199296462784, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('654874f480e107ec52ce1bac'), ObjectId('654874fe80e107ec52ce1bb2'), ObjectId('6548750980e107ec52ce1bb8'), ObjectId('6548751380e107ec52ce1bbe'), ObjectId('6548751d80e107ec52ce1bc4')], 'startedAt': datetime.datetime(2023, 11, 6, 5, 8, 58, 554000), 'updatedAt': datetime.datetime(2023, 11, 6, 5, 9, 59, 887000), 'completedAt': datetime.datetime(2023, 11, 6, 5, 9, 59, 887000)}]
# 2023-11-06 14:10:00+00:00 2023-11-06 05:10:00 2023-11-06 05:11:00
# 공지현 Stroop 1 6541ef360d097eeb1f713c94
# [{'_id': ObjectId('6548753080e107ec52ce1bd7'), 'userId': ObjectId('6541ef360d097eeb1f713c94'), 'time': 60, 'pureFocusTime': 11, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 18.333333333333332, 'efficiencyHCount': 5, 'efficiencyMCount': 0, 'efficiencyLCount': 0, 'capacity': 16.564281041024753, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6548753b80e107ec52ce1bdb'), ObjectId('6548754580e107ec52ce1be1'), ObjectId('6548754f80e107ec52ce1be7'), ObjectId('6548755980e107ec52ce1bed'), ObjectId('6548756380e107ec52ce1bf3')], 'startedAt': datetime.datetime(2023, 11, 6, 5, 10, 8, 942000), 'updatedAt': datetime.datetime(2023, 11, 6, 5, 11, 10, 457000), 'completedAt': datetime.datetime(2023, 11, 6, 5, 11, 10, 456000)}]
# 2023-11-06 14:11:00+00:00 2023-11-06 05:11:00 2023-11-06 05:12:00
# 공지현 Rest 2 6541ef360d097eeb1f713c94
# [{'_id': ObjectId('6548758280e107ec52ce1c06'), 'userId': ObjectId('6541ef360d097eeb1f713c94'), 'time': 63, 'pureFocusTime': 35, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 55.55555555555556, 'efficiencyHCount': 0, 'efficiencyMCount': 5, 'efficiencyLCount': 1, 'capacity': 23.083757374873414, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6548758c80e107ec52ce1c0a'), ObjectId('6548759680e107ec52ce1c10'), ObjectId('654875a080e107ec52ce1c16'), ObjectId('654875aa80e107ec52ce1c1c'), ObjectId('654875b580e107ec52ce1c22'), ObjectId('654875bf80e107ec52ce1c28')], 'startedAt': datetime.datetime(2023, 11, 6, 5, 11, 30, 253000), 'updatedAt': datetime.datetime(2023, 11, 6, 5, 12, 34, 553000), 'completedAt': datetime.datetime(2023, 11, 6, 5, 12, 34, 553000)}]
# 2023-11-06 14:12:00+00:00 2023-11-06 05:12:00 2023-11-06 05:13:00
# 공지현 Stroop 2 6541ef360d097eeb1f713c94
# [{'_id': ObjectId('654875cb80e107ec52ce1c3b'), 'userId': ObjectId('6541ef360d097eeb1f713c94'), 'time': 61, 'pureFocusTime': 6, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 9.836065573770492, 'efficiencyHCount': 4, 'efficiencyMCount': 1, 'efficiencyLCount': 1, 'capacity': 16.086411142665053, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('654875d580e107ec52ce1c3f'), ObjectId('654875df80e107ec52ce1c45'), ObjectId('654875e980e107ec52ce1c4b'), ObjectId('654875f380e107ec52ce1c51'), ObjectId('654875fe80e107ec52ce1c57'), ObjectId('6548760880e107ec52ce1c5d')], 'startedAt': datetime.datetime(2023, 11, 6, 5, 12, 43, 124000), 'updatedAt': datetime.datetime(2023, 11, 6, 5, 13, 46, 369000), 'completedAt': datetime.datetime(2023, 11, 6, 5, 13, 46, 368000)}]
# 2023-11-06 14:13:00+00:00 2023-11-06 05:13:00 2023-11-06 05:14:00
# 공지현 Rest 3 6541ef360d097eeb1f713c94
# [{'_id': ObjectId('6548761780e107ec52ce1c70'), 'userId': ObjectId('6541ef360d097eeb1f713c94'), 'time': 61, 'pureFocusTime': 28, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 45.90163934426229, 'efficiencyHCount': 1, 'efficiencyMCount': 3, 'efficiencyLCount': 1, 'capacity': 26.12344466946913, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6548762280e107ec52ce1c74'), ObjectId('6548762c80e107ec52ce1c7a'), ObjectId('6548763680e107ec52ce1c80'), ObjectId('6548764080e107ec52ce1c86'), ObjectId('6548764a80e107ec52ce1c8c'), ObjectId('6548765480e107ec52ce1c92')], 'startedAt': datetime.datetime(2023, 11, 6, 5, 13, 59, 768000), 'updatedAt': datetime.datetime(2023, 11, 6, 5, 15, 2, 425000), 'completedAt': datetime.datetime(2023, 11, 6, 5, 15, 2, 41000)}]
# 2023-11-06 14:15:00+00:00 2023-11-06 05:15:00 2023-11-06 05:16:00
# 공지현 Stroop 3 6541ef360d097eeb1f713c94
# [{'_id': ObjectId('6548765d80e107ec52ce1ca5'), 'userId': ObjectId('6541ef360d097eeb1f713c94'), 'time': 61, 'pureFocusTime': 5, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 8.19672131147541, 'efficiencyHCount': 3, 'efficiencyMCount': 2, 'efficiencyLCount': 0, 'capacity': 16.420681173415026, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6548766780e107ec52ce1ca9'), ObjectId('6548767180e107ec52ce1caf'), ObjectId('6548767c80e107ec52ce1cb5'), ObjectId('6548768680e107ec52ce1cbb'), ObjectId('6548769080e107ec52ce1cc1'), ObjectId('6548769a80e107ec52ce1cc7')], 'startedAt': datetime.datetime(2023, 11, 6, 5, 15, 9, 534000), 'updatedAt': datetime.datetime(2023, 11, 6, 5, 16, 12, 465000), 'completedAt': datetime.datetime(2023, 11, 6, 5, 16, 12, 136000)}]
# 2023-11-06 16:00:00+00:00 2023-11-06 07:00:00 2023-11-06 07:01:00
# 유영석 Rest 1 6530ca13cac8ae0cdd40e573
# [{'_id': ObjectId('65488efd3c7d07e9092f7689'), 'userId': ObjectId('6530ca13cac8ae0cdd40e573'), 'time': 65, 'pureFocusTime': 16, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 24.615384615384617, 'efficiencyHCount': 0, 'efficiencyMCount': 3, 'efficiencyLCount': 3, 'capacity': 24.858394523301033, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId
 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('65486dfa9113bf9e08eac4b7'), ObjectId('65486e049113bf9e08eac4c3'), ObjectId('65486e0e9113bf9e08eac4cf'), ObjectId('65486e189113bf9e08eac4db'), ObjectId('65486e229113bf9e08eac4e7')], 'startedAt': datetime.datetime(2023, 11, 6, 4, 39, 12, 85000), 'updatedAt': datetime.datetime(2023, 11, 6, 4, 40, 13, 273000), 'completedAt': datetime.datetime(2023, 11, 6, 4, 40, 13, 273000)}]
# 2023-11-06 13:40:00+00:00 2023-11-06 04:40:00 2023-11-06 04:41:00
# 임은수 Stroop 1 6543335b9113bf9e08eaad48
# [{'_id': ObjectId('65486e3a9113bf9e08eac506'), 'userId': ObjectId('6543335b9113bf9e08eaad48'), 'time': 62, 'pureFocusTime': 59, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 95.16129032258065, 'efficiencyHCount': 0, 'efficiencyMCount': 5, 'efficiencyLCount': 0, 'capacity': 49.83561728128809, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('65486e449113bf9e08eac510'), ObjectId('65486e4e9113bf9e08eac51c'), ObjectId('65486e599113bf9e08eac528'), ObjectId('65486e639113bf9e08eac534'), ObjectId('65486e6d9113bf9e08eac540'), ObjectId('65486e779113bf9e08eac54c')], 'startedAt': datetime.datetime(2023, 11, 6, 4, 40, 26, 558000), 'updatedAt': datetime.datetime(2023, 11, 6, 4, 41, 29, 872000), 'completedAt': datetime.datetime(2023, 11, 6, 4, 41, 29, 827000)}]
# 2023-11-06 13:41:00+00:00 2023-11-06 04:41:00 2023-11-06 04:42:00
# 임은수 Rest 2 6543335b9113bf9e08eaad48
# [{'_id': ObjectId('65486e949113bf9e08eac571'), 'userId': ObjectId('6543335b9113bf9e08eaad48'), 'time': 60, 'pureFocusTime': 60, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 100, 'efficiencyHCount': 0, 'efficiencyMCount': 4, 'efficiencyLCount': 1, 'capacity': 82.51597016793335, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('65486e9f9113bf9e08eac57b'), ObjectId('65486ea99113bf9e08eac587'), ObjectId('65486eb39113bf9e08eac593'), ObjectId('65486ebd9113bf9e08eac59f'), ObjectId('65486ec79113bf9e08eac5a8')], 'startedAt': datetime.datetime(2023, 11, 6, 4, 41, 56, 868000), 'updatedAt': datetime.datetime(2023, 11, 6, 4, 42, 58, 442000), 'completedAt': datetime.datetime(2023, 11, 6, 4, 42, 58, 442000)}]
# 2023-11-06 13:43:00+00:00 2023-11-06 04:43:00 2023-11-06 04:44:00
# 임은수 Stroop 2 6543335b9113bf9e08eaad48
# [{'_id': ObjectId('65486ed69113bf9e08eac5c7'), 'userId': ObjectId('6543335b9113bf9e08eaad48'), 'time': 4, 'pureFocusTime': 4, 'pauseTime': 0, 'recordCount': 0, 'efficiency': 100, 'efficiencyHCount': 0, 'efficiencyMCount': 0, 'efficiencyLCount': 0, 'capacity': 0, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [], 'startedAt': datetime.datetime(2023, 11, 6, 4, 43, 2, 117000), 'updatedAt': datetime.datetime(2023, 11, 6, 4, 43, 7, 31000), 'completedAt': datetime.datetime(2023, 11, 6, 4, 43, 7, 31000)}, {'_id': ObjectId('65486ee99113bf9e08eac5e3'), 'userId': ObjectId('6543335b9113bf9e08eaad48'), 'time': 61, 'pureFocusTime': 55, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 90.1639344262295, 'efficiencyHCount': 1, 'efficiencyMCount': 4, 'efficiencyLCount': 0, 'capacity': 36.78632395435311, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId
# 2023-11-07 16:09:00+00:00 2023-11-07 07:09:00 2023-11-07 07:10:00
# 김필수 Rest 1 6548af6e9113bf9e08eae4ee
# [{'_id': ObjectId('6549e2b49113bf9e08eb32c8'), 'userId': ObjectId('6548af6e9113bf9e08eae4ee'), 'time': 64, 'pureFocusTime': 31, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 48.4375, 'efficiencyHCount': 1, 'efficiencyMCount': 4, 'efficiencyLCount': 1, 'capacity': 33.3142368454377, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6549e2be9113bf9e08eb32d2'), ObjectId('6549e2c89113bf9e08eb32de'), ObjectId('6549e2d29113bf9e08eb32ea'), ObjectId('6549e2dc9113bf9e08eb32f6'), ObjectId('6549e2e69113bf9e08eb3305'), ObjectId('6549e2f09113bf9e08eb3312')], 'startedAt': datetime.datetime(2023, 11, 7, 7, 9, 40, 331000), 'updatedAt': datetime.datetime(2023, 11, 7, 7, 10, 45, 971000), 'completedAt': datetime.datetime(2023, 11, 7, 7, 10, 45, 970000)}]
# 2023-11-07 16:10:00+00:00 2023-11-07 07:10:00 2023-11-07 07:11:00
# 김필수 Stroop 1 6548af6e9113bf9e08eae4ee
# [{'_id': ObjectId('6549e2ff9113bf9e08eb333a'), 'userId': ObjectId('6548af6e9113bf9e08eae4ee'), 'time': 63, 'pureFocusTime': 12, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 19.047619047619047, 'efficiencyHCount': 0, 'efficiencyMCount': 1, 'efficiencyLCount': 5, 'capacity': 14.357275881374882, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6549e3099113bf9e08eb334a'), ObjectId('6549e3139113bf9e08eb3359'), ObjectId('6549e31d9113bf9e08eb3368'), ObjectId('6549e3289113bf9e08eb3374'), ObjectId('6549e3329113bf9e08eb3389'), ObjectId('6549e33c9113bf9e08eb339b')], 'startedAt': datetime.datetime(2023, 11, 7, 7, 10, 55, 629000), 'updatedAt': datetime.datetime(2023, 11, 7, 7, 11, 59, 624000), 'completedAt': datetime.datetime(2023, 11, 7, 7, 11, 59, 624000)}]
# 2023-11-07 16:12:00+00:00 2023-11-07 07:12:00 2023-11-07 07:13:00
# 김필수 Rest 2 6548af6e9113bf9e08eae4ee
# [{'_id': ObjectId('6549e3549113bf9e08eb33cc'), 'userId': ObjectId('6548af6e9113bf9e08eae4ee'), 'time': 61, 'pureFocusTime': 30, 'pauseTime': 0, 'recordCount': 5, 'efficiency': 49.18032786885246, 'efficiencyHCount': 4, 'efficiencyMCount': 1, 'efficiencyLCount': 0, 'capacity': 36.89447637245282, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6549e35e9113bf9e08eb33e2'), ObjectId('6549e3689113bf9e08eb33f4'), ObjectId('6549e3729113bf9e08eb3406'), ObjectId('6549e37c9113bf9e08eb3418'), ObjectId('6549e3869113bf9e08eb3427'), ObjectId('6549e3909113bf9e08eb3436')], 'startedAt': datetime.datetime(2023, 11, 7, 7, 12, 20, 8000), 'updatedAt': datetime.datetime(2023, 11, 7, 7, 13, 24, 31000), 'completedAt': datetime.datetime(2023, 11, 7, 7, 13, 22, 450000)}]
# [{'_id': ObjectId('6549edc89113bf9e08eb417a'), 'userId': ObjectId('65435b2d9113bf9e08eaadb8'), 'time': 68, 'pureFocusTime': 65, 'pauseTime': 0, 'recordCount': 6, 'efficiency': 95.58823529411765, 'efficiencyHCount': 0, 'efficiencyMCount': 3, 'efficiencyLCount': 3, 'capacity': 93.11112556533415, 'stress': 0, 'interruptedCount': 0, 'interruptedCountInApp': 0, 'pauseCount': 0, 'focusTimerState': 'COMPLETED', 'withBand': True, 'focusTimerRecordIds': [ObjectId('6549edd29113bf9e08eb4193'), ObjectId('6549eddc9113bf9e08eb419f'), ObjectId('6549ede79113bf9e08eb41ab'), ObjectId('6549edf19113bf9e08eb41b7'), ObjectId('6549edfb9113bf9e08eb41c3'), ObjectId('6549ee059113bf9e08eb41cf')], 'startedAt': datetime.datetime(2023, 11, 7, 7, 56, 56, 515000), 'updatedAt': datetime.datetime(2023, 11, 7, 7, 58, 5, 898000), 'completedAt': datetime.datetime(2023, 11, 7, 7, 58, 5, 898000)}]

# %%
new_df
# Out:
#    Name                                Email   Label  Trial  Wrong Answer  \
# 0   조문규              jooyoung.kim@epitech.eu    Rest      1             0
# 1   조문규              jooyoung.kim@epitech.eu  Stroop      1             1
# 2   조문규              jooyoung.kim@epitech.eu    Rest      2             0
# 3   조문규              jooyoung.kim@epitech.eu  Stroop      2             0
# 4   조문규              jooyoung.kim@epitech.eu    Rest      3             0
# 5   조문규              jooyoung.kim@epitech.eu  Stroop      3             0
# 6   공지현                     gjh2672@nate.com    Rest      1             0
# 7   공지현                     gjh2672@nate.com  Stroop      1             0
# 8   공지현                     gjh2672@nate.com    Rest      2             0
# 9   공지현                     gjh2672@nate.com  Stroop      2             0
# 10  공지현                     gjh2672@nate.com    Rest      3             0
# 11  공지현                     gjh2672@nate.com  Stroop      3             1
# 12  유영석                  modern331@naver.com    Rest      1             0
# 13  유영석                  modern331@naver.com  Stroop      1             0
# 14  유영석                  modern331@naver.com    Rest      2             0
# 15  유영석                  modern331@naver.com  Stroop      2             0
# 16  유영석                  modern331@naver.com    Rest      3             0
# 17  유영석                  modern331@naver.com  Stroop      3             0
# 18  임은수                    les0807@kakao.com    Rest      1             0
# 19  임은수                    les0807@kakao.com  Stroop      1             1
# 20  임은수                    les0807@kakao.com    Rest      2             0
# 21  임은수                    les0807@kakao.com  Stroop      2             0
# 22  임은수                    les0807@kakao.com    Rest      3             0
# 23  임은수                    les0807@kakao.com  Stroop      3             1
# 24  서지은  bhp8bghcq7@privaterelay.appleid.com    Rest      1             0
# 25  서지은  bhp8bghcq7@privaterelay.appleid.com  Stroop      1             1
# 26  서지은  bhp8bghcq7@privaterelay.appleid.com    Rest      2             0
# 27  서지은  bhp8bghcq7@privaterelay.appleid.com  Stroop      2             0
# 28  서지은  bhp8bghcq7@privaterelay.appleid.com    Rest      3             0
# 29  서지은  bhp8bghcq7@privaterelay.appleid.com  Stroop      3             0
# 30  김필수                   gorh1234@gmail.com    Rest      1             0
# 31  김필수                   gorh1234@gmail.com  Stroop      1             1
# 32  김필수                   gorh1234@gmail.com    Rest      2             0
# 33  김필수                   gorh1234@gmail.com  Stroop      2             0
# 34  김필수                   gorh1234@gmail.com    Rest      3             0
# 35  김필수                   gorh1234@gmail.com  Stroop      3             0
# 33  1.2  False 2023-11-07 16:14:00  6548af6e9113bf9e08eae4ee
# 34  0.0  False 2023-11-07 16:15:00  6548af6e9113bf9e08eae4ee
# 35  1.3  False 2023-11-07 16:17:00  6548af6e9113bf9e08eae4ee
# 36  0.0  False 2023-11-07 16:49:00  65435b2d9113bf9e08eaadb8
# 37  1.0  False 2023-11-07 16:50:00  65435b2d9113bf9e08eaadb8
# 38  0.0  False 2023-11-07 16:52:00  65435b2d9113bf9e08eaadb8
# 39  1.0  False 2023-11-07 16:53:00  65435b2d9113bf9e08eaadb8
# 40  0.0  False 2023-11-07 16:54:00  65435b2d9113bf9e08eaadb8
# 41  0.9  False 2023-11-07 16:56:00  65435b2d9113bf9e08eaadb8
#
#               focus_timer_id
# 0   65489a3a3c7d07e9092f7975
# 1   65489a7d3c7d07e9092f79b0
# 2   65489ad33c7d07e9092f79fc
# 3   65489b193c7d07e9092f7a37
# 4   65489b683c7d07e9092f7a6c
# 5   65489bb23c7d07e9092f7aa7
# 6   654874ea80e107ec52ce1ba8
# 7   6548753080e107ec52ce1bd7
# 8   6548758280e107ec52ce1c06
# 9   654875cb80e107ec52ce1c3b
# 10  6548761780e107ec52ce1c70
# 11  6548765d80e107ec52ce1ca5
# 12  65488efd3c7d07e9092f7689
# 13  65488f443c7d07e9092f76be
# 14  65488f8f3c7d07e9092f76fc
# 15  65488fd43c7d07e9092f7731
# 16  654890203c7d07e9092f7770
# 17  654890673c7d07e9092f77b1
# 18  65486df09113bf9e08eac4ad
# 19  65486e3a9113bf9e08eac506
# 20  65486e949113bf9e08eac571
# 21  65486ee99113bf9e08eac5e3
# 22  65486f369113bf9e08eac63f
# 23  65486f7d9113bf9e08eac674
# 24  6549df699113bf9e08eb2d3f
# 25  6549dfb89113bf9e08eb2df6
# 26  6549e0149113bf9e08eb2e97
# 27  6549e05c9113bf9e08eb2f16
# 28  6549e0bf9113bf9e08eb2fde
# 29  6549e1079113bf9e08eb3054
# 30  6549e2b49113bf9e08eb32c8
# 31  6549e2ff9113bf9e08eb333a
# 32  6549e3549113bf9e08eb33cc
# 33  6549e3c49113bf9e08eb34a7
# 34  6549e42c9113bf9e08eb3551
# 35  6549e47a9113bf9e08eb35e9
# 36  6549ec0a9113bf9e08eb3e5b
# 37  6549ec549113bf9e08eb3ee7
# 38  6549eca29113bf9e08eb3f79
# 39  6549ece79113bf9e08eb4002
# 40  6549ed339113bf9e08eb4094
# 41  6549edc89113bf9e08eb417a

# %%
new_df.to_csv("stroop_test_2.csv")

# %%
save_df = new_df

# %%
save_df
# Out:
#    Name                    Email   Label  Trial  Wrong Answer   RT  IsDev  \
# 0   조문규  jooyoung.kim@epitech.eu    Rest      1             0  0.0   True
# 1   조문규  jooyoung.kim@epitech.eu  Stroop      1             1  2.0   True
# 2   조문규  jooyoung.kim@epitech.eu    Rest      2             0  0.0   True
# 3   조문규  jooyoung.kim@epitech.eu  Stroop      2             0  1.3   True
# 4   조문규  jooyoung.kim@epitech.eu    Rest      3             0  0.0   True
# 5   조문규  jooyoung.kim@epitech.eu  Stroop      3             0  1.1   True
# 18 2023-11-06 13:39:00  6543335b9113bf9e08eaad48  65486df09113bf9e08eac4ad
# 19 2023-11-06 13:40:00  6543335b9113bf9e08eaad48  65486e3a9113bf9e08eac506
# 20 2023-11-06 13:41:00  6543335b9113bf9e08eaad48  65486e949113bf9e08eac571
# 21 2023-11-06 13:43:00  6543335b9113bf9e08eaad48  65486ee99113bf9e08eac5e3
# 22 2023-11-06 13:44:00  6543335b9113bf9e08eaad48  65486f369113bf9e08eac63f
# 23 2023-11-06 13:45:00  6543335b9113bf9e08eaad48  65486f7d9113bf9e08eac674

# %%
import s3fs
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # plot eeg

# %%
def eeg_filter(eeg, btype, eeg_sr=250, freq_high=0.5, freq_stop=60, freq_band=[1, 50], eeg_butter_order=3, ):
    f_n = eeg_sr / 2
    b = 1
    a = 1
    if btype == "highpass":
        b, a = signal.butter(
            eeg_butter_order, freq_high / f_n, btype=btype, analog=False
        )
    elif btype == "bandstop":
        b, a = signal.butter(
            eeg_butter_order,
            [(freq_stop - 1) / f_n, (freq_stop + 1) / f_n],
            btype,
            analog=False,
        )
    elif btype == "bandpass":
        b, a = signal.butter(
            eeg_butter_order,
            np.array(freq_band) / f_n,
            btype,
            analog=False,
        )
    filtered_eeg = signal.filtfilt(
        b,
        a,
        eeg,
        axis=0,
        padtype="odd",
        padlen=3 * (max(len(b), len(a)) - 1),
    )
    return filtered_eeg
def apply_filter(eeg_raw_data):
#     applied_bandpass = eeg_filter(eeg_raw_data, "bandstop")
    
    applied_bandpass = eeg_filter(eeg_raw_data, "bandpass")
    return applied_bandpass
    
def epoching_for_fft(eeg, nperseg):
    epochs = []
    overlap = len(eeg) - nperseg
    epoch_count = len(eeg) // nperseg + 1
    
    first_seg = eeg[0:nperseg]
    second_seg = eeg[len(eeg)//2 - nperseg//2 : len(eeg)//2 + nperseg//2]
    third_seg = eeg[-nperseg:]
    
    epochs.append(first_seg)
    epochs.append(second_seg)
    epochs.append(third_seg)
    
    return epochs
    
def segment_per_second(eeg, nperseg):
    epochs = [eeg[i * nperseg: (i + 1) * nperseg] for i in range(len(eeg) // nperseg)]
    
    return epochs
def psd_norm(psd):
    denom = psd.sum(axis=1, keepdims=True)
    normed = psd / denom
    return normed


def calculate_psd_from_fft(eeg, nperseg, relative=True):
    MIN_FREQ_INDEX = 1
    MAX_FREQ_INDEX = 55
        
    all_psds = []
    segments = segment_per_second(eeg, nperseg)
    for segment in segments:
        segment_psds = []
#         epochs = epoching_for_fft(segment, 128)
#         for epoch in epochs:
#             fft_result = np.fft.fft(epoch)
#             power_spectrum = np.sqrt(np.abs(fft_result)**2)
#             psd = power_spectrum / len(epoch) / 250 * 2
#             # 1
        fft_result = np.fft.fft(segment)
        power_spectrum = np.sqrt(np.abs(fft_result)**2)
        psd = power_spectrum / len(segment) / 250 * 2
        # 아랫줄만 밀어넣을 것
        segment_psds.append(psd)
    
        segment_psds = np.array(segment_psds)
        f = np.fft.fftfreq(len(segment), 1/250)
        idx_crop = (MIN_FREQ_INDEX <= f) & (f <= MAX_FREQ_INDEX)
        segment_psds = segment_psds[:, idx_crop]
        f = f[idx_crop]
        if relative:
            segment_psd_avg = psd_norm(segment_psds)
            segment_psd_avg = np.mean(segment_psd_avg, axis=0)
        all_psds.append(segment_psd_avg)
    return f, np.array(all_psds)


def load_raw_data_list(userId, crownId, bucket):
    path_obj = f'{bucket}/focus-timer/{userId}/{crownId}'
#     print(path_obj)
    raw_data_files = sf.glob(f'{path_obj}//**')
    raw_data_files.sort()
    
    return raw_data_files
def get_efficiency(focus_ch2, case):
    제외시간 = 0
    기준시간 = 60
    
    new_focus_ch2 = focus_ch2 / np.max(focus_ch2)
    personal_focus = focus_ch2
    initial_efficiency = len(list(filter(lambda x : 0 < x <= 1.0, personal_focus[제외시간:기준시간])))
    initial_hyper_efficiency = len(list(filter(lambda x : x <= 0, personal_focus[제외시간:기준시간])))
    baseline_org = np.mean(personal_focus[제외시간:기준시간])
#     norm = personal_focus[제외시간:기준시간]/np.max(personal_focus[제외시간:기준시간])
#     baseline_org = np.mean(norm)
#     print(baseline_org)
    
    baseline_std = np.std(personal_focus[제외시간:기준시간])
    
    if case == 1:
        baseline = list(filter(lambda x : baseline_org - baseline_std <= x <= baseline_org + baseline_std, personal_focus[제외시간:기준시간]))
        baseline = np.mean(baseline)
    else:
        baseline = baseline_org
    
    hyper_baseline = 0.05
    normal_efficiency = len(list(filter(lambda x : hyper_baseline < x <= baseline, personal_focus[기준시간:])))
    hyper_efficiency = len(list(filter(lambda x : x <= hyper_baseline, personal_focus[기준시간:])))
    efficiency = (initial_efficiency + normal_efficiency) / len(personal_focus) + (initial_hyper_efficiency + hyper_efficiency) / len(personal_focus) * 2
    return baseline, efficiency
def get_past_efficiency(focus_ch2):
    기준시간 = 60
    initial_efficiency = len(list(filter(lambda x : 0.2 < x <= 1.2, focus_ch2[:기준시간])))
    initial_hyper_efficiency = len(list(filter(lambda x : x <= 0.2, focus_ch2[:기준시간])))
    baseline = np.mean(focus_ch2[:기준시간])
    baseline_std = np.std(focus_ch2[:기준시간])
    hyper_ratio = baseline - 0.74
    hyper_ratio = 1 / (1 + np.e ** (-hyper_ratio))
    
    hyper_baseline = 0.2
    if baseline > 0.25:
        hyper_baseline = 0.2
    else:
        hyper_baseline = baseline*0.8
    normal_efficiency = len(list(filter(lambda x : hyper_baseline < x <= baseline, focus_ch2[기준시간:])))
    hyper_efficiency = len(list(filter(lambda x : x <= hyper_baseline, focus_ch2[기준시간:])))
    efficiency = (initial_efficiency + normal_efficiency) / len(focus_ch2) + (initial_hyper_efficiency + hyper_efficiency) / len(focus_ch2) * 2
    return baseline, efficiency
def psd_norm_without_epoch(psd):
    denom = psd.sum(axis=0, keepdims=True)
    normed = psd / denom
    return normed
def calculate_PSD_without_epoch(eeg, nperseg, relative=True):
    # Calculate relative PSD
    MIN_FREQ_INDEX = 1
    MAX_FREQ_INDEX = 55
    f, psd = welch(eeg, fs=250, nperseg=nperseg, axis=0, window="hamming")
    idx_crop = (MIN_FREQ_INDEX <= f) & (f <= MAX_FREQ_INDEX)
    psd = psd[idx_crop]
    f = f[idx_crop]
    if relative:
        psd = psd_norm_without_epoch(psd)
    return f, psd

# %%
user_id = '6541ef360d097eeb1f713c94'
focus_id = '6548761780e107ec52ce1c70'

# %%
보여줘요(user_id, focus_id)
# Out:
# current [ 1.         -3.55807539  5.13960568 -4.09091662  2.05784773 -0.60997051
#   0.06152167]
# current [ 1.         -3.55807539  5.13960568 -4.09091662  2.05784773 -0.60997051
#   0.06152167]
# 1.0

# %%
def 보여줘요(user_id, focus_id):
    # ('653255c70d097eeb1f6f441e', '65362ceb0d097eeb1f6fbe77')
    s3 = boto3.resource('s3')
    # bucket = 'focusmate-public-dev'
    bucket = 'focusmate-public-dev'

    sf = s3fs.S3FileSystem(anon=False)
    s3 = boto3.resource('s3')
    raw_data_files = load_raw_data_list(user_id, focus_id, bucket)
    thetas = []
    alphas = []
    betas = []
    total_raw_ch1 = []
    total_raw_ch2 = []
    
    for raw_data_file in raw_data_files:
        path_split = raw_data_file.split('/')
#         print(path_split)
        key1 = path_split[0]
        key2 = f'{path_split[1]}/{path_split[2]}/{path_split[3]}/{path_split[4]}'
        uploaded_file_s3_obj = s3.Object(key1, key2)
        raw_json = json.loads(uploaded_file_s3_obj.get()['Body'].read())

        eeg_raw_ch1 = raw_json['eegChannel1']
        eeg_raw_ch2 = raw_json['eegChannel2']
        total_raw_ch1 += eeg_raw_ch1
        total_raw_ch2 += eeg_raw_ch2
    # total_raw_ch2 = list(filter(lambda x : x < 8388607, total_raw_ch2))
    filtered_eeg_raw_ch2 = apply_filter(total_raw_ch2)
    f2, psds_ch2 = calculate_psd_from_fft(filtered_eeg_raw_ch2, 250)
    delta_ch2 = np.sum(psds_ch2[:,1:4], axis=1)
    theta_ch2 = np.sum(psds_ch2[:,3:7], axis=1)
    alpha_ch2 = np.sum(psds_ch2[:,7:13], axis=1)
    beta_ch2 = np.sum(psds_ch2[:,13:30], axis=1)
    gamma_ch2 = np.sum(psds_ch2[:,24:], axis=1)

    tbr_ch2 = alpha_ch2 / gamma_ch2
    focus_ch2 = tbr_ch2
    baseline, efficiency = get_efficiency(focus_ch2, 0)
    print(efficiency)
    plt.figure(0, figsize=(30, 10))
    plt.subplot(2,1, 1)
    plt.plot(focus_ch2, label='AGR')
    plt.hlines([0.05, baseline], 0, len(focus_ch2), color='red', linestyle='solid', linewidth=2)
    plt.vlines(60, 0, 2.0, color='gray', linestyle='solid', linewidth=3)
    plt.title('TBR')
    plt.subplot(2,1,2)
    plt.plot(alpha_ch2, label='alpha(A)')
    plt.plot(gamma_ch2, label='gamma(G)')
    plt.legend()
    plt.title('Beta & Theta')
    plt.show()
    plt.close()
    plt.plot(total_raw_ch2)
    plt.show()

# %%
def stroop_test(email, start_time, duration):

    checker = MongoDBChecker(connection_string, dev_mode=row["IsDev"])

    user_id = checker.get_user_id_from_email(row["Email"])
    result = checker.get_focustimer_ids_from_user_id_and_range(user_id, start_time.tz_localize(UTC), duration)
        
        
    try:
        focus_timer_id = result[-1]["_id"]
    except:
        return None
    
    보여줘요(user_id, focus_id)
    
    return
